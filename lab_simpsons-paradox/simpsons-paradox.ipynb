# %% [markdown]
# # lab_simpsons-paradox
#
# Hi Data Scientists,
#
# Welcome to the third lab!  In this lab, you will explore using pandas to explore real-word datasets and find if Simpson's Paradox appears in several different datasets.
#
#
# ### Labs are Collaborative
#
# In your lab section (right now!), find a person or two around you and form a group.  Work on this together, making sure all of you understand each component of the lab.
#
#
# ### Getting Help
#
# Remember, there are a lot of ways to get help if you find yourself stuck:
#
# 1. In lab section, your TA, CAs, and your peers are here for you!
#
#
# 2. On the course Piazza page: https://piazza.com/illinois/fall2019/stat107
#
#
# 3. Office Hours:
#
#   - Open office hours **every Monday, Wednesday, Thursday, and Friday** from 4:00pm - 6:30pm in 23 Illini Hall
#
#   - Prof. Wade + Prof. Karle are available every Wednesday from 8:30am - 10:00am in 2215 Siebel Center

# %% [markdown]
# # Puzzle 1: Homecoming Date Night
#
# Imagine you and your partner are trying to find the perfect restaurant for a homecoming date night dinner!  Knowing this process can lead to hours of arguments, you seek out the answer to all of life’s questions: *online reviews*.
#
# The dataset `Black Dog Reviews.csv` (already provided for you as part of the lab code you checked out from git) contains data showing all of the males and females that have reviewed Black Dog in the past year and whether or not they recommended it.  The dataset `Papa Dels Reviews.csv` contains the same information for Papa Dels.
#
#
# ## 1.1: Data Cleaning
#
# Unfortunately, this data was not as tidy as all of our data has been so far. :(
#
# - Open `Black Dog Reviews.csv` and `Papa Dels Reviews.csv` CSV file using any program that can edit spreadsheets.  This can be Microsoft Excel (if you have it installed) or you can upload it to Google Drive and edit it with Google Sheets.
# - Modify the file to ensure all rows that in the `Gender` column has the same value for the two gender categories (as `Male` and `Female`) found in this dataset.
# - Finally, make sure to save the file as a CSV so you can used your cleaned dataset for this lab.
#
#
# ## 1.2. Loading Your DataSet
#
# Load the DataSets you just cleaned into Python:

# %%
# Import the pandas library as pd
import pandas as pd

# %%
df_black_dog = pd.read_csv("Black Dog Reviews.csv")
df_black_dog
# Out:
#     Gender Recommend Black Dog
# 0     Male                 Yes
# 1     Male                 Yes
# 2     Male                 Yes
# 3     Male                 Yes
# 4     Male                 Yes
# 5     Male                  No
# 6     Male                  No
# 7     Male                  No
# 8     Male                  No
# 9     Male                  No
# 10    Male                  No
# 11    Male                  No
# 12    Male                  No
# 13    Male                  No
# 14    Male                  No
# 15  Female                 Yes
# 16  Female                 Yes
# 17  Female                 Yes
# 18  Female                 Yes
# 19  Female                 Yes
# 20  Female                 Yes
# 21  Female                 Yes
# 22  Female                 Yes
# 23  Female                 Yes
# 24  Female                 Yes
# 25  Female                 Yes
# 26  Female                 Yes
# 27  Female                 Yes
# 28  Female                 Yes
# 29  Female                 Yes
# 30  Female                 Yes
# 31  Female                 Yes
# 32  Female                 Yes
# 33  Female                 Yes
# 34  Female                 Yes
# 35  Female                  No
# 36  Female                  No
# 37  Female                  No
# 38  Female                  No
# 39  Female                  No

# %%
## == TEST CASES for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_black_dog) == 40), "The dataframe does not appear to have correct dataset loaded"

# %%
df_papa_del = pd.read_csv("Papa Dels Reviews.csv")
df_papa_del
# Out:
#     Gender Recommend Papa Dels
# 0     Male                 Yes
# 1     Male                 Yes
# 2     Male                 Yes
# 3     Male                 Yes
# 4     Male                 Yes
# 5     Male                 Yes
# 6     Male                 Yes
# 7     Male                 Yes
# 8     Male                 Yes
# 9     Male                 Yes
# 10    Male                 Yes
# 11    Male                 Yes
# 12    Male                 Yes
# 13    Male                 Yes
# 14    Male                 Yes
# 15    Male                 Yes
# 16    Male                 Yes
# 17    Male                 Yes
# 18    Male                  No
# 19    Male                  No
# 20    Male                  No
# 21    Male                  No
# 22    Male                  No
# 23    Male                  No
# 24    Male                  No
# 25    Male                  No
# 26    Male                  No
# 27    Male                  No
# 28    Male                  No
# 29    Male                  No
# 30    Male                  No
# 31    Male                  No
# 32    Male                  No
# 33    Male                  No
# 34    Male                  No
# 35    Male                  No
# 36  Female                 Yes
# 37  Female                 Yes
# 38  Female                 Yes
# 39  Female                 Yes
# 40  Female                 Yes
# 41  Female                 Yes
# 42  Female                 Yes
# 43  Female                 Yes
# 44  Female                 Yes
# 45  Female                  No

# %%
## == TEST CASES for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_papa_del) == 46), "The dataframe does not appear to have correct dataset loaded"

# %% [markdown]
# ## 1.3. Analysis
#
# We want to use the Black Dog dataset to calculate the percentage of women who recommended Black Dog.  Then calculate the percentage of men who recommended Black Dog:

# %%
black_dog_female = df_black_dog[df_black_dog['Gender'] == 'Female']
black_dog_femaleY = black_dog_female[black_dog_female['Recommend Black Dog'] == 'Yes']
black_dog_female_percent = len(black_dog_femaleY)/len(black_dog_female)
black_dog_female_percent
# Out:
# 0.8

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(black_dog_female_percent == 0.8), "The percentage of Female who recommended Black Dog does not appear to have correct calculated"

# %%
black_dog_male = df_black_dog[df_black_dog['Gender'] == 'Male']
black_dog_maleY = black_dog_male[black_dog_male['Recommend Black Dog'] == 'Yes']

black_dog_male_percent = len(black_dog_maleY)/len(black_dog_male)
black_dog_male_percent
# Out:
# 0.3333333333333333

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(black_dog_male_percent == (1/3)), "The percentage of Male who recommended Black Dog does not appear to have correct calculated"

# %% [markdown]
# Similarly, use the Papa Dels dataset to calculate the percentage of women who recommended Papa Dels.  Then calculate the percentage of men who recommended Papa Dels:

# %%
papa_dels_female = df_papa_del[df_papa_del['Gender'] == 'Female']
papa_dels_femaleY = papa_dels_female[papa_dels_female['Recommend Papa Dels'] == "Yes"]

papa_dels_female_percent = len(papa_dels_femaleY)/len(papa_dels_female)
papa_dels_female_percent
# Out:
# 0.9

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(papa_dels_female_percent == 0.9), "The percentage of Female who recommended Papa Dels does not appear to have correctly calculated"

# %%
papa_dels_male = df_papa_del[df_papa_del['Gender'] == 'Male']
papa_dels_maleY = papa_dels_male[papa_dels_male['Recommend Papa Dels'] == "Yes"]

papa_dels_male_percent = len(papa_dels_maleY)/len(papa_dels_male)
papa_dels_male_percent
# Out:
# 0.5

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(papa_dels_male_percent == 0.5), "The percentage of Male who recommended Papa Dels does not appear to have correct calculated"

# %% [markdown]
# ### Observe the Results
#
# Run the following cell to format all of your answers as a DataFrame:

# %%
pd.DataFrame( [
    {'Female': black_dog_female_percent, 'Male': black_dog_male_percent },
    {'Female': papa_dels_female_percent, 'Male': papa_dels_male_percent },    
], index=['Black Dog', 'Papa Dels'])
# Out:
#            Female      Male
# Black Dog     0.8  0.333333
# Papa Dels     0.9  0.500000

# %% [markdown]
# ❓ **Question** ❓: Should your homecoming date night be at Black Dog or Papa Dels?
#
# - Dows "Black Dog" (Row #1) have higher values or "Papa Dels" (Row #2) have higher values?

# %% [markdown]
# ## 1.4. Analysis - Part 2
#
# For our final analysis, let's examine the **overall** percentage of people who recommend each restaurant:

# %%
black_dogY = df_black_dog[df_black_dog['Recommend Black Dog'] == 'Yes']
black_dog_recommended_percent = len(black_dogY)/len(df_black_dog)
black_dog_recommended_percent
# Out:
# 0.625

# %%
## == TEST CASES for Puzzle 1.4 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(black_dog_recommended_percent == 0.625), "The percentage of Overall who recommended Black Dog does not appear to have correct calculated"

# %%
papa_delsY = df_papa_del[df_papa_del["Recommend Papa Dels"] == 'Yes']

papa_dels_recommended_percent = len(papa_delsY)/len(df_papa_del) 
papa_dels_recommended_percent
# Out:
# 0.5869565217391305

# %%
## == TEST CASES for Puzzle 1.4 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(papa_dels_recommended_percent == (27/46)), "The percentage of Overall who recommended Papa Dels does not appear to have correct calculated"

# %% [markdown]
# ### Observe the Results
#
# Run the following cell to format all of your answers as a DataFrame:

# %%
pd.DataFrame( [
    {'Female': black_dog_female_percent, 'Male': black_dog_male_percent, 'Overall': black_dog_recommended_percent },
    {'Female': papa_dels_female_percent, 'Male': papa_dels_male_percent, 'Overall': papa_dels_recommended_percent },
], index=['Black Dog', 'Papa Dels'] )
# Out:
#            Female      Male   Overall
# Black Dog     0.8  0.333333  0.625000
# Papa Dels     0.9  0.500000  0.586957

# %% [markdown]
# ❓ **Question** ❓: Should your homecoming date night be at Black Dog or Papa Dels?
#
# - Dows "Black Dog" (Row #1) have higher values or "Papa Dels" (Row #2) have higher values for **Overall**?

# %% [markdown]
# # Puzzle 2: Twitch and Shoes

# %% [markdown]
# From the "Hello" dataset we created on the first day of class, we picked two random questions for us to explore:
#
# - Do you view video on Twitch at least once a week?
# - How many pairs of shoes do you have?

# %% [markdown]
# ## 2.1: Load the Dataset
#
# - You can find the "Hello" dataset here (make sure to log in with your @illinois.edu address to access it): https://docs.google.com/spreadsheets/d/1LB4E89GoVi5yezEfHhopbI5BMxodSG7VvoznkaAkMAQ/edit#gid=0

# %%
# Read the hello dataset into a DataFrame
df_hello = pd.read_csv('hello.csv')
df_hello
# Out:
#           Name                      Major School Year     Type  \
# 0         Wade           Computer Science       Other  Android
# 1        Karle                 Statistics       Other   iPhone
# 2         noor  global studies/statistics   Sophomore   iPhone
# 3     Jonathan          Political Science      Senior   iPhone
# 4        Clare                 Statistics   Sophomore   iPhone
# ..         ...                        ...         ...      ...
# 161  Stephanie          Political Science      Junior   iPhone
# 162      Cindy     biomedical engineering      Senior  Android
# 163      Talal       Information sciences   Sophomore   iPhone
# 164       John     Statistics or Business    Freshman   iPhone
# 165     Anisha                        Mcb      Junior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 0     Windows-based computer          2.0         0         1         0
# 1    Mac OS X-based computer          1.0         0         0         0
# 2    Mac OS X-based computer          1.0         0         0         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 4    Mac OS X-based computer          1.0         1         0         0
# ..                       ...          ...       ...       ...       ...
# 161  Mac OS X-based computer          NaN         1         0         0
# 162   Windows-based computer          1.0         1         0         0
# 163   Windows-based computer          1.0         0         1         0
# 164   Windows-based computer          1.0         1         0         0
# 165  Mac OS X-based computer          1.0         0         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 0               0  ...           0                 Yes
# 1               0  ...           0                 Yes
# 2               0  ...           0                  No
# 3               0  ...           0                 Yes
# 4               0  ...           0                 Yes
# ..            ...  ...         ...                 ...
# 161             0  ...           0                  No
# 162             0  ...           0                  No
# 163             0  ...           0                 Yes
# 164             0  ...           1                  No
# 165             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 0    Significant -- I am a wizard when it comes to ...                   2
# 1    Some Python -- I have had one class or written...                  20
# 2    No programming background -- is Python Taylor ...                   3
# 3    No Python, but I've done some programming in o...                   2
# 4    Some Python -- I have had one class or written...                   1
# ..                                                 ...                 ...
# 161  No programming background -- is Python Taylor ...                   1
# 162  No Python, but I've done some programming in o...                   1
# 163  No Python, but I've done some programming in o...                   0
# 164  No programming background -- is Python Taylor ...                   1
# 165  Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0              3.0       2.0             8.0          4.0
# 1              1.0       2.0             7.0         20.0
# 2              3.0       1.0             7.0         20.0
# 3              4.0       1.0             6.0         10.0
# 4              4.0       0.0             8.0         20.0
# ..             ...       ...             ...          ...
# 161            2.0       9.0             7.0         30.0
# 162            2.0       1.0             8.0          3.0
# 163            3.0       2.0             8.0         12.0
# 164            1.0       1.0             7.0         12.0
# 165            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 1                       24.0    Extrovert
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 4                       30.0     Ambivert
# ..                       ...          ...
# 161                     12.0    Extrovert
# 162                      8.0     Ambivert
# 163                     25.0     Ambivert
# 164                     60.0    Introvert
# 165                     15.0    Introvert
#
# [166 rows x 31 columns]

# %%
## == TEST CASES for Puzzle 2.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_hello) == 166), "The dataframe does not appear to have correct dataset loaded"

# %% [markdown]
# ## 2.2: Observation Subsets
#
# Create two DataFrames that contain subsets of our data: one DataFrame that includes everyone who has watches Twitch at least once a week and one DataFrame that includes everyone who does not watch twitch at least once a week:

# %%
df_twitch = df_hello[df_hello['Has Twitch'] == 1]
df_twitch
# Out:
#            Name                                              Major  \
# 5         Dhruv                                   Computer science
# 9    Edward/Edd                        CS, business data analysis?
# 10        Taige                                          Math + CS
# 13         Andy                                         Statistics
# 44       Andrew                                          CS + STAT
# 45          Leo                                                CS?
# 51     Zhoutian                               Computer Engineering
# 61        Tyler                                  actuarial science
# 67        Vivek                                   Computer science
# 77      Michael                                  Actuarial Science
# 90      Stephen                      Psychology & Computer Science
# 103        Cole                                  Political Science
# 126     Jaesung                                          Economics
# 129       Miles                                                GIS
# 141        Andi  Computer Science + Statistics or Statistics ma...
# 142       Jason                                            History
# 143      Austin                   Computer Science and Linguistics
# 148        Matt                               Information Sciences
# 154       David                               Information Sciences
# 160        Nate                                         Statistics
# 164        John                             Statistics or Business
#
#     School Year     Type                 Computer  Straw Holes  Has Dogs  \
# 5     Sophomore  Android   Windows-based computer          1.0         0
# 9        Senior  Android     Linux-based computer          1.0         0
# 10     Freshman   iPhone   Windows-based computer          1.0         0
# 13       Senior   iPhone   Windows-based computer          1.0         0
# 44       Junior   iPhone   Windows-based computer          1.0         1
# 45     Freshman   iPhone   Windows-based computer          1.0         0
# 51     Freshman   iPhone   Windows-based computer          1.0         0
# 61     Freshman  Android   Windows-based computer          1.0         1
# 67    Sophomore   iPhone   Windows-based computer          2.0         0
# 77       Senior  Android   Windows-based computer          1.0         0
# 90     Freshman  Android  Mac OS X-based computer          2.0         1
# 103      Junior   iPhone  Mac OS X-based computer          1.0         1
# 126      Senior   iPhone  Mac OS X-based computer          1.0         0
# 129      Senior   iPhone   Windows-based computer          0.0         1
# 141   Sophomore   iPhone   Windows-based computer          1.0         1
# 142      Senior  Android   Windows-based computer          1.0         1
# 143      Junior  Android   Windows-based computer          1.0         0
# 148   Sophomore  Android     Linux-based computer          1.0         0
# 154   Sophomore  Android   Windows-based computer          1.0         1
# 160   Sophomore   iPhone   Windows-based computer          1.0         1
# 164    Freshman   iPhone   Windows-based computer          1.0         1
#
#      Has Cats  Has Fish  Has Chickens  ...  Has Twitch  Programmed before?  \
# 5           0         0             0  ...           1                 Yes
# 9           0         0             0  ...           1                 Yes
# 10          1         0             0  ...           1                 Yes
# 13          0         0             0  ...           1                 Yes
# 44          1         0             0  ...           1                 Yes
# 45          0         1             0  ...           1                 Yes
# 51          0         1             0  ...           1                 Yes
# 61          1         0             0  ...           1                 Yes
# 67          0         1             0  ...           1                 Yes
# 77          0         0             0  ...           1                 Yes
# 90          1         0             0  ...           1                 Yes
# 103         0         0             0  ...           1                 Yes
# 126         0         0             0  ...           1                 Yes
# 129         1         0             1  ...           1                 Yes
# 141         0         0             0  ...           1                 Yes
# 142         0         0             0  ...           1                 Yes
# 143         0         1             0  ...           1                 Yes
# 148         0         0             0  ...           1                 Yes
# 154         1         0             0  ...           1                 Yes
# 160         0         0             0  ...           1                 Yes
# 164         0         0             0  ...           1                  No
#
#                                      Python Background  Statistics Courses  \
# 5    Some Python -- I have had one class or written...                   0
# 9    Some Python -- I have had one class or written...                   1
# 10   Some Python -- I have had one class or written...                   4
# 13   Some Python -- I have had one class or written...                   3
# 44   No Python, but I've done some programming in o...                   4
# 45   Some Python -- I have had one class or written...                   0
# 51   No Python, but I've done some programming in o...                   1
# 61   Some Python -- I have had one class or written...                   2
# 67   Some Python -- I have had one class or written...                   0
# 77   Some Python -- I have had one class or written...                   2
# 90   Some Python -- I have had one class or written...                   0
# 103  No Python, but I've done some programming in o...                   2
# 126  No Python, but I've done some programming in o...                   3
# 129  Some Python -- I have had one class or written...                   1
# 141  Some Python -- I have had one class or written...                   2
# 142  Some Python -- I have had one class or written...                   1
# 143  Significant -- I am a wizard when it comes to ...                   2
# 148  Some Python -- I have had one class or written...                   1
# 154  No Python, but I've done some programming in o...                   0
# 160  No Python, but I've done some programming in o...                   1
# 164  No programming background -- is Python Taylor ...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 5              3.0       2.0             6.0          4.0
# 9              3.0       2.0             8.0          5.0
# 10             3.0       0.0             6.0          6.0
# 13            10.0       2.0             7.0          3.0
# 44             4.0       1.0             5.0          2.0
# 45             3.0       1.0             8.5          3.0
# 51             9.0       0.0             7.0          6.0
# 61             3.0       3.0             8.0          5.0
# 67             3.0       1.0             6.0          4.0
# 77             1.0       2.0             8.0          6.0
# 90            10.0       0.0             7.5          2.0
# 103            4.0       1.0             6.0         11.0
# 126           12.0       2.0             7.0          5.0
# 129            1.0       0.0             7.0          3.0
# 141            1.0       1.0             6.0          3.0
# 142            1.0       1.0             7.0          2.0
# 143            3.0       1.0             7.0          2.0
# 148            4.0       2.0            10.0          6.0
# 154            2.5       2.0             6.0          1.0
# 160            8.0       4.0             8.0         12.0
# 164            1.0       1.0             7.0         12.0
#
#      People Texted Yesterday  Personality
# 5                       11.0    Introvert
# 9                       10.0     Ambivert
# 10                      15.0    Introvert
# 13                      70.0     Ambivert
# 44                       2.0     Ambivert
# 45                      20.0     Ambivert
# 51                       6.0     Ambivert
# 61                      10.0    Introvert
# 67                      30.0    Extrovert
# 77                       9.0     Ambivert
# 90                       8.0    Introvert
# 103                      3.0    Introvert
# 126                      3.0    Introvert
# 129                     10.0     Ambivert
# 141                     10.0    Introvert
# 142                      1.0    Introvert
# 143                      3.0    Introvert
# 148                     15.0     Ambivert
# 154                      3.0     Ambivert
# 160                    100.0     Ambivert
# 164                     60.0    Introvert
#
# [21 rows x 31 columns]

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_twitch) == 21), "The dataframe does not appear to have been correct subset"

# %%
df_no_twitch = df_hello[df_hello['Has Twitch'] == 0]
df_no_twitch
# Out:
#           Name                      Major School Year     Type  \
# 0         Wade           Computer Science       Other  Android
# 1        Karle                 Statistics       Other   iPhone
# 2         noor  global studies/statistics   Sophomore   iPhone
# 3     Jonathan          Political Science      Senior   iPhone
# 4        Clare                 Statistics   Sophomore   iPhone
# ..         ...                        ...         ...      ...
# 159     Julisa                Mathematics   Sophomore   iPhone
# 161  Stephanie          Political Science      Junior   iPhone
# 162      Cindy     biomedical engineering      Senior  Android
# 163      Talal       Information sciences   Sophomore   iPhone
# 165     Anisha                        Mcb      Junior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 0     Windows-based computer          2.0         0         1         0
# 1    Mac OS X-based computer          1.0         0         0         0
# 2    Mac OS X-based computer          1.0         0         0         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 4    Mac OS X-based computer          1.0         1         0         0
# ..                       ...          ...       ...       ...       ...
# 159   Windows-based computer          2.0         0         0         0
# 161  Mac OS X-based computer          NaN         1         0         0
# 162   Windows-based computer          1.0         1         0         0
# 163   Windows-based computer          1.0         0         1         0
# 165  Mac OS X-based computer          1.0         0         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 0               0  ...           0                 Yes
# 1               0  ...           0                 Yes
# 2               0  ...           0                  No
# 3               0  ...           0                 Yes
# 4               0  ...           0                 Yes
# ..            ...  ...         ...                 ...
# 159             0  ...           0                 Yes
# 161             0  ...           0                  No
# 162             0  ...           0                  No
# 163             0  ...           0                 Yes
# 165             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 0    Significant -- I am a wizard when it comes to ...                   2
# 1    Some Python -- I have had one class or written...                  20
# 2    No programming background -- is Python Taylor ...                   3
# 3    No Python, but I've done some programming in o...                   2
# 4    Some Python -- I have had one class or written...                   1
# ..                                                 ...                 ...
# 159  Some Python -- I have had one class or written...                   0
# 161  No programming background -- is Python Taylor ...                   1
# 162  No Python, but I've done some programming in o...                   1
# 163  No Python, but I've done some programming in o...                   0
# 165  Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0              3.0       2.0             8.0          4.0
# 1              1.0       2.0             7.0         20.0
# 2              3.0       1.0             7.0         20.0
# 3              4.0       1.0             6.0         10.0
# 4              4.0       0.0             8.0         20.0
# ..             ...       ...             ...          ...
# 159            3.0       3.0             5.0         10.0
# 161            2.0       9.0             7.0         30.0
# 162            2.0       1.0             8.0          3.0
# 163            3.0       2.0             8.0         12.0
# 165            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 1                       24.0    Extrovert
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 4                       30.0     Ambivert
# ..                       ...          ...
# 159                     15.0    Extrovert
# 161                     12.0    Extrovert
# 162                      8.0     Ambivert
# 163                     25.0     Ambivert
# 165                     15.0    Introvert
#
# [145 rows x 31 columns]

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_no_twitch) == 145), "The dataframe does not appear to have been correct subset"

# %% [markdown]
# ## 2.3: Average Number of Pairs of Shoes
#
# Find the average number of pairs of shoes of each group:

# %%
twitch_avg_shoes = df_twitch['Shoes Owned'].mean()
twitch_avg_shoes
# Out:
# 4.904761904761905

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(twitch_avg_shoes == 103/21),  "The average number of pairs of shoes in twitch dataset does not appear to seem correct. Make sure you are taking mean of the correct variable."

# %%
no_twitch_avg_shoes = df_no_twitch['Shoes Owned'].mean()
no_twitch_avg_shoes
# Out:
# 9.38888888888889

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(no_twitch_avg_shoes == 1352 / 144),  "The average number of pairs of shoes in no twitch dataset does not appear to seem correct. Make sure you are taking mean of the correct variable."

# %% [markdown]
# ## 2.4. Observations
#
# Answer the next two questions with 1-2 sentences each.  The cells after the question text are editable -- you should double-click and replace the text with your answer:

# %% [markdown]
# ### Q1: Is there a difference in the number of shoes owned between the two groups?

# %% [markdown]
# Yes, there is a difference. The group that uses Twitch owns lesser shoes on average than the group that doesn't use Twitch.

# %% [markdown]
# ### Q2: What might be some possible confounding variable in this result?

# %% [markdown]
# Low income - The target audience of Twitch are mainly teenagers who are not financially independent to buy shoes themselves.

# %% [markdown]
# # Finale!
#
# You're almost done -- congratulations!
#
# You need to do two more things:
#
# 1. Save your work.  To do this, create a **notebook checkpoint** by using the menu within the notebook to go **File -> Save and Checkpoint**
#
# 2. After you have saved and checkpointed, exit this notebook and return to the Data Science Discovery page on how to use git to turn this notebook into the course!
