# %% [markdown]
# # EC Notebook for Lecture 4: Blocking and Conditionals
#
# This extra credit Python notebook will let you practice the material you saw in lecture!  Completing all parts of this notebook will earn +1 extra credit point to your grade in STAT 107!
#
# This notebook is worth +1 if turned in before 11:30am on **Friday, Sept. 6** *(30 minutes before the next STAT 107 lecture)*.  You can feel free to complete it anytime for extra practice.

# %% [markdown]
# ## 1. Loading pandas and importing data
#
# For this notebook, we will continue to use the "Hello" dataset introduced last lecture!
#
# Using your @illinois.edu address, download the dataset as a CSV and **make sure to save or move it to the same directory as this notebook**: https://docs.google.com/spreadsheets/d/1LB4E89GoVi5yezEfHhopbI5BMxodSG7VvoznkaAkMAQ/edit#gid=0
#
# Use the following cell to load the pandas library and read the DataSet as a DataFrame:

# %%
import pandas as pd
df = pd.read_csv("hello dataset - Sheet1.csv")

# %% [markdown]
# ## 2. Finising the Lecture Problem
#
# In lecture, we left you with a final puzzle.  From the lecture handout:
#
# > Use Python to create a control group of 20 students, using blocking to control for the influence we suspect having more than 1 siblings might have.  Make sure you have an equal number of students with 0 or 1 sibling and an equal number of students with 2 or more siblings.
#
# We will complete this in four separate steps to get practice on each part.
#
# #### 2.1: Sibling Block #1
#
# Creating a DataFrame that contains all students with 0 or 1 siblings and call it `block1`:

# %%
block1 = df[ df["Siblings"] <= 1]
block1
# Out:
#          Name                           Major School Year     Type  \
# 2        noor       global studies/statistics   Sophomore   iPhone
# 3    Jonathan               Political Science      Senior   iPhone
# 4       Clare                      Statistics   Sophomore   iPhone
# 7       Margo                       Chemistry      Senior   iPhone
# 8     Natalia                      Psychology    Freshman   iPhone
# ..        ...                             ...         ...      ...
# 155    Serena                            Math      Senior   iPhone
# 158       Ash  Consumer Economics and Finance      Junior   iPhone
# 162     Cindy          biomedical engineering      Senior  Android
# 164      John          Statistics or Business    Freshman   iPhone
# 165    Anisha                             Mcb      Junior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 2    Mac OS X-based computer          1.0         0         0         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 4    Mac OS X-based computer          1.0         1         0         0
# 7    Mac OS X-based computer          0.5         1         0         0
# 8                      Other          1.0         0         0         0
# ..                       ...          ...       ...       ...       ...
# 155  Mac OS X-based computer          2.0         0         1         0
# 158  Mac OS X-based computer          1.0         0         0         0
# 162   Windows-based computer          1.0         1         0         0
# 164   Windows-based computer          1.0         1         0         0
# 165  Mac OS X-based computer          1.0         0         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 2               0  ...           0                  No
# 3               0  ...           0                 Yes
# 4               0  ...           0                 Yes
# 7               0  ...           0                  No
# 8               0  ...           0                  No
# ..            ...  ...         ...                 ...
# 155             0  ...           0                 Yes
# 158             0  ...           0                 Yes
# 162             0  ...           0                  No
# 164             0  ...           1                  No
# 165             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 2    No programming background -- is Python Taylor ...                   3
# 3    No Python, but I've done some programming in o...                   2
# 4    Some Python -- I have had one class or written...                   1
# 7    No programming background -- is Python Taylor ...                   0
# 8    No programming background -- is Python Taylor ...                   1
# ..                                                 ...                 ...
# 155  Some Python -- I have had one class or written...                   4
# 158  Some Python -- I have had one class or written...                   4
# 162  No Python, but I've done some programming in o...                   1
# 164  No programming background -- is Python Taylor ...                   1
# 165  Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 2              3.0       1.0             7.0         20.0
# 3              4.0       1.0             6.0         10.0
# 4              4.0       0.0             8.0         20.0
# 7              5.0       1.0             8.0          8.0
# 8              4.0       1.0             7.0          5.0
# ..             ...       ...             ...          ...
# 155            4.0       0.0             7.0         15.0
# 158            3.0       1.0             6.0         20.0
# 162            2.0       1.0             8.0          3.0
# 164            1.0       1.0             7.0         12.0
# 165            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 4                       30.0     Ambivert
# 7                       20.0     Ambivert
# 8                        4.0     Ambivert
# ..                       ...          ...
# 155                      5.0     Ambivert
# 158                     10.0     Ambivert
# 162                      8.0     Ambivert
# 164                     60.0    Introvert
# 165                     15.0    Introvert
#
# [100 rows x 31 columns]

# %% [markdown]
# #### 2.2: Sibling Block #2
#
# Create a DataFrame that contains all students with 2 or more siblings and call it `block2`:

# %%
block2 = df[ df["Siblings"] >= 2]
block2
# Out:
#            Name                        Major School Year     Type  \
# 0          Wade             Computer Science       Other  Android
# 1         Karle                   Statistics       Other   iPhone
# 5         Dhruv             Computer science   Sophomore  Android
# 6          Alex                      Physics      Junior  Android
# 9    Edward/Edd  CS, business data analysis?      Senior  Android
# ..          ...                          ...         ...      ...
# 157       Donny         Information Sciences      Junior   iPhone
# 159      Julisa                  Mathematics   Sophomore   iPhone
# 160        Nate                   Statistics   Sophomore   iPhone
# 161   Stephanie            Political Science      Junior   iPhone
# 163       Talal         Information sciences   Sophomore   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 0     Windows-based computer          2.0         0         1         0
# 1    Mac OS X-based computer          1.0         0         0         0
# 5     Windows-based computer          1.0         0         0         0
# 6     Windows-based computer          1.0         0         0         0
# 9       Linux-based computer          1.0         0         0         0
# ..                       ...          ...       ...       ...       ...
# 157   Windows-based computer          1.0         0         0         0
# 159   Windows-based computer          2.0         0         0         0
# 160   Windows-based computer          1.0         1         0         0
# 161  Mac OS X-based computer          NaN         1         0         0
# 163   Windows-based computer          1.0         0         1         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 0               0  ...           0                 Yes
# 1               0  ...           0                 Yes
# 5               0  ...           1                 Yes
# 6               0  ...           0                 Yes
# 9               0  ...           1                 Yes
# ..            ...  ...         ...                 ...
# 157             0  ...           0                  No
# 159             0  ...           0                 Yes
# 160             0  ...           1                 Yes
# 161             0  ...           0                  No
# 163             0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 0    Significant -- I am a wizard when it comes to ...                   2
# 1    Some Python -- I have had one class or written...                  20
# 5    Some Python -- I have had one class or written...                   0
# 6    Some Python -- I have had one class or written...                   1
# 9    Some Python -- I have had one class or written...                   1
# ..                                                 ...                 ...
# 157  No Python, but I've done some programming in o...                   1
# 159  Some Python -- I have had one class or written...                   0
# 160  No Python, but I've done some programming in o...                   1
# 161  No programming background -- is Python Taylor ...                   1
# 163  No Python, but I've done some programming in o...                   0
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0              3.0       2.0             8.0          4.0
# 1              1.0       2.0             7.0         20.0
# 5              3.0       2.0             6.0          4.0
# 6              0.0       2.0             6.0          2.0
# 9              3.0       2.0             8.0          5.0
# ..             ...       ...             ...          ...
# 157            2.0       2.0             7.0          3.0
# 159            3.0       3.0             5.0         10.0
# 160            8.0       4.0             8.0         12.0
# 161            2.0       9.0             7.0         30.0
# 163            3.0       2.0             8.0         12.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 1                       24.0    Extrovert
# 5                       11.0    Introvert
# 6                       74.0    Introvert
# 9                       10.0     Ambivert
# ..                       ...          ...
# 157                     20.0     Ambivert
# 159                     15.0    Extrovert
# 160                    100.0     Ambivert
# 161                     12.0    Extrovert
# 163                     25.0     Ambivert
#
# [65 rows x 31 columns]

# %% [markdown]
# #### 2.3: Selecting equal groups from block1 and block2
#
# **Randomly** select an equal number of students from each of `block1` and `block2` and store them in `control1` and `control2`.  We will combine both groups to make the full control group:

# %%
control1 = block1.sample(n = 10)
control1
# Out:
#          Name                           Major School Year     Type  \
# 23      Yosup  Computer Science + Mathematics    Freshman  Android
# 56    Kamayah  Mathematics & Computer Science      Junior   iPhone
# 59     Qichao            Computer engineering      Senior   iPhone
# 90    Stephen   Psychology & Computer Science    Freshman  Android
# 131     Medha       Math and Computer Science   Sophomore  Android
# 97      Oscar       Engineering CS or Math&CS    Freshman   iPhone
# 17      Yijie    Computer Science+Mathematics    Freshman  Android
# 3    Jonathan               Political Science      Senior   iPhone
# 2        noor       global studies/statistics   Sophomore   iPhone
# 72       Isha                      Psychology    Freshman   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 23   Mac OS X-based computer          2.0         0         0         0
# 56    Windows-based computer          2.0         0         1         0
# 59   Mac OS X-based computer          1.0         0         0         0
# 90   Mac OS X-based computer          2.0         1         1         0
# 131  Mac OS X-based computer          1.0         0         0         0
# 97    Windows-based computer          1.0         0         0         0
# 17   Mac OS X-based computer          2.0         0         0         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 2    Mac OS X-based computer          1.0         0         0         0
# 72    Windows-based computer          2.0         1         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 23              0  ...           0                 Yes
# 56              0  ...           0                 Yes
# 59              0  ...           0                 Yes
# 90              0  ...           1                 Yes
# 131             0  ...           0                 Yes
# 97              0  ...           0                 Yes
# 17              0  ...           0                 Yes
# 3               0  ...           0                 Yes
# 2               0  ...           0                  No
# 72              0  ...           0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 23   No Python, but I've done some programming in o...                   0
# 56   No Python, but I've done some programming in o...                   1
# 59   Some Python -- I have had one class or written...                   3
# 90   Some Python -- I have had one class or written...                   0
# 131  Some Python -- I have had one class or written...                   1
# 97   No Python, but I've done some programming in o...                   1
# 17   Some Python -- I have had one class or written...                   0
# 3    No Python, but I've done some programming in o...                   2
# 2    No programming background -- is Python Taylor ...                   3
# 72   Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 23             4.0       1.0             6.0          4.0
# 56             4.0       0.0             7.0         25.0
# 59             6.0       0.0             7.0          7.0
# 90            10.0       0.0             7.5          2.0
# 131            2.0       1.0             7.0          6.0
# 97             5.0       1.0             7.0          5.0
# 17             4.0       0.0             7.0         10.0
# 3              4.0       1.0             6.0         10.0
# 2              3.0       1.0             7.0         20.0
# 72             3.0       1.0             8.0         15.0
#
#      People Texted Yesterday  Personality
# 23                       6.0     Ambivert
# 56                       6.0    Introvert
# 59                       9.0     Ambivert
# 90                       8.0    Introvert
# 131                     15.0     Ambivert
# 97                      15.0     Ambivert
# 17                      10.0     Ambivert
# 3                        8.0    Introvert
# 2                       10.0    Introvert
# 72                      10.0    Introvert
#
# [10 rows x 31 columns]

# %%
control2 = block2.sample(n = 10)
control2
# Out:
#           Name                 Major School Year     Type  \
# 104     Eunice            Journalism   Sophomore   iPhone
# 58       Diego           CS + Anthro      Junior   iPhone
# 21       Colin     Actuarial Science    Freshman   iPhone
# 14        Gail           Art History      Senior  Android
# 54    Saharish     Political Science      Senior   iPhone
# 30   Folashade     Political Science   Sophomore   iPhone
# 156      Sofia     Political Science      Junior   iPhone
# 43       Louie        CS + Astronomy    Freshman   iPhone
# 163      Talal  Information sciences   Sophomore   iPhone
# 81        Rami            Psychology    Freshman  Android
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 104  Mac OS X-based computer          2.0         0         0         0
# 58    Windows-based computer          1.0         0         0         0
# 21    Windows-based computer          1.0         1         0         0
# 14    Windows-based computer          1.0         1         0         0
# 54   Mac OS X-based computer          1.0         1         0         0
# 30   Mac OS X-based computer          1.0         0         0         0
# 156  Mac OS X-based computer          1.0         0         0         0
# 43   Mac OS X-based computer          2.0         1         1         0
# 163   Windows-based computer          1.0         0         1         0
# 81   Mac OS X-based computer          2.0         0         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 104             0  ...           0                 Yes
# 58              0  ...           0                 Yes
# 21              0  ...           0                 Yes
# 14              0  ...           0                 Yes
# 54              0  ...           0                  No
# 30              0  ...           0                  No
# 156             0  ...           0                  No
# 43              0  ...           0                 Yes
# 163             0  ...           0                 Yes
# 81              0  ...           0                  No
#
#                                      Python Background  Statistics Courses  \
# 104  Some Python -- I have had one class or written...                   1
# 58   Some Python -- I have had one class or written...                   2
# 21   No Python, but I've done some programming in o...                   1
# 14   No Python, but I've done some programming in o...                   2
# 54   No programming background -- is Python Taylor ...                   1
# 30   No programming background -- is Python Taylor ...                   0
# 156  No programming background -- is Python Taylor ...                   1
# 43   Some Python -- I have had one class or written...                   1
# 163  No Python, but I've done some programming in o...                   0
# 81   No programming background -- is Python Taylor ...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 104            3.0       2.0             6.0          6.0
# 58             2.0       2.0             7.0         10.0
# 21             2.0       2.0             7.0          NaN
# 14             3.0       2.0             7.0          8.0
# 54             5.0       2.0             6.5         10.0
# 30            10.0       2.0             6.0          4.0
# 156            8.0       2.0             7.0          3.0
# 43             2.0       2.0             8.0          2.0
# 163            3.0       2.0             8.0         12.0
# 81             4.0       2.0             6.0          5.0
#
#      People Texted Yesterday  Personality
# 104                      7.0    Introvert
# 58                       8.0     Ambivert
# 21                      27.0     Ambivert
# 14                       2.0    Introvert
# 54                      17.0     Ambivert
# 30                       7.0    Introvert
# 156                      5.0     Ambivert
# 43                       2.0    Introvert
# 163                     25.0     Ambivert
# 81                       6.0     Ambivert
#
# [10 rows x 31 columns]

# %% [markdown]
# #### 2.4. Combine the two sub-groups into a single control group
#
# Use the following code to merge the contents of `control1` and `control2` together into one large group called `control`:

# %%
control = pd.concat([control1,control2])
control
# Out:
#           Name                           Major School Year     Type  \
# 23       Yosup  Computer Science + Mathematics    Freshman  Android
# 56     Kamayah  Mathematics & Computer Science      Junior   iPhone
# 59      Qichao            Computer engineering      Senior   iPhone
# 90     Stephen   Psychology & Computer Science    Freshman  Android
# 131      Medha       Math and Computer Science   Sophomore  Android
# 97       Oscar       Engineering CS or Math&CS    Freshman   iPhone
# 17       Yijie    Computer Science+Mathematics    Freshman  Android
# 3     Jonathan               Political Science      Senior   iPhone
# 2         noor       global studies/statistics   Sophomore   iPhone
# 72        Isha                      Psychology    Freshman   iPhone
# 104     Eunice                      Journalism   Sophomore   iPhone
# 58       Diego                     CS + Anthro      Junior   iPhone
# 21       Colin               Actuarial Science    Freshman   iPhone
# 14        Gail                     Art History      Senior  Android
# 54    Saharish               Political Science      Senior   iPhone
# 30   Folashade               Political Science   Sophomore   iPhone
# 156      Sofia               Political Science      Junior   iPhone
# 43       Louie                  CS + Astronomy    Freshman   iPhone
# 163      Talal            Information sciences   Sophomore   iPhone
# 81        Rami                      Psychology    Freshman  Android
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 23   Mac OS X-based computer          2.0         0         0         0
# 56    Windows-based computer          2.0         0         1         0
# 59   Mac OS X-based computer          1.0         0         0         0
# 90   Mac OS X-based computer          2.0         1         1         0
# 131  Mac OS X-based computer          1.0         0         0         0
# 97    Windows-based computer          1.0         0         0         0
# 17   Mac OS X-based computer          2.0         0         0         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 2    Mac OS X-based computer          1.0         0         0         0
# 72    Windows-based computer          2.0         1         0         0
# 104  Mac OS X-based computer          2.0         0         0         0
# 58    Windows-based computer          1.0         0         0         0
# 21    Windows-based computer          1.0         1         0         0
# 14    Windows-based computer          1.0         1         0         0
# 54   Mac OS X-based computer          1.0         1         0         0
# 30   Mac OS X-based computer          1.0         0         0         0
# 156  Mac OS X-based computer          1.0         0         0         0
# 43   Mac OS X-based computer          2.0         1         1         0
# 163   Windows-based computer          1.0         0         1         0
# 81   Mac OS X-based computer          2.0         0         0         0
#
#      Has Chickens  ...  Has Twitch  Programmed before?  \
# 23              0  ...           0                 Yes
# 56              0  ...           0                 Yes
# 59              0  ...           0                 Yes
# 90              0  ...           1                 Yes
# 131             0  ...           0                 Yes
# 97              0  ...           0                 Yes
# 17              0  ...           0                 Yes
# 3               0  ...           0                 Yes
# 2               0  ...           0                  No
# 72              0  ...           0                 Yes
# 104             0  ...           0                 Yes
# 58              0  ...           0                 Yes
# 21              0  ...           0                 Yes
# 14              0  ...           0                 Yes
# 54              0  ...           0                  No
# 30              0  ...           0                  No
# 156             0  ...           0                  No
# 43              0  ...           0                 Yes
# 163             0  ...           0                 Yes
# 81              0  ...           0                  No
#
#                                      Python Background  Statistics Courses  \
# 23   No Python, but I've done some programming in o...                   0
# 56   No Python, but I've done some programming in o...                   1
# 59   Some Python -- I have had one class or written...                   3
# 90   Some Python -- I have had one class or written...                   0
# 131  Some Python -- I have had one class or written...                   1
# 97   No Python, but I've done some programming in o...                   1
# 17   Some Python -- I have had one class or written...                   0
# 3    No Python, but I've done some programming in o...                   2
# 2    No programming background -- is Python Taylor ...                   3
# 72   Some Python -- I have had one class or written...                   1
# 104  Some Python -- I have had one class or written...                   1
# 58   Some Python -- I have had one class or written...                   2
# 21   No Python, but I've done some programming in o...                   1
# 14   No Python, but I've done some programming in o...                   2
# 54   No programming background -- is Python Taylor ...                   1
# 30   No programming background -- is Python Taylor ...                   0
# 156  No programming background -- is Python Taylor ...                   1
# 43   Some Python -- I have had one class or written...                   1
# 163  No Python, but I've done some programming in o...                   0
# 81   No programming background -- is Python Taylor ...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 23             4.0       1.0             6.0          4.0
# 56             4.0       0.0             7.0         25.0
# 59             6.0       0.0             7.0          7.0
# 90            10.0       0.0             7.5          2.0
# 131            2.0       1.0             7.0          6.0
# 97             5.0       1.0             7.0          5.0
# 17             4.0       0.0             7.0         10.0
# 3              4.0       1.0             6.0         10.0
# 2              3.0       1.0             7.0         20.0
# 72             3.0       1.0             8.0         15.0
# 104            3.0       2.0             6.0          6.0
# 58             2.0       2.0             7.0         10.0
# 21             2.0       2.0             7.0          NaN
# 14             3.0       2.0             7.0          8.0
# 54             5.0       2.0             6.5         10.0
# 30            10.0       2.0             6.0          4.0
# 156            8.0       2.0             7.0          3.0
# 43             2.0       2.0             8.0          2.0
# 163            3.0       2.0             8.0         12.0
# 81             4.0       2.0             6.0          5.0
#
#      People Texted Yesterday  Personality
# 23                       6.0     Ambivert
# 56                       6.0    Introvert
# 59                       9.0     Ambivert
# 90                       8.0    Introvert
# 131                     15.0     Ambivert
# 97                      15.0     Ambivert
# 17                      10.0     Ambivert
# 3                        8.0    Introvert
# 2                       10.0    Introvert
# 72                      10.0    Introvert
# 104                      7.0    Introvert
# 58                       8.0     Ambivert
# 21                      27.0     Ambivert
# 14                       2.0    Introvert
# 54                      17.0     Ambivert
# 30                       7.0    Introvert
# 156                      5.0     Ambivert
# 43                       2.0    Introvert
# 163                     25.0     Ambivert
# 81                       6.0     Ambivert
#
# [20 rows x 31 columns]

# %%
## == TEST CASES for Puzzle 2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( len(control) == 20 ), "Your control group must only have 20 courses in it."
assert( len(control[control.Siblings < 2] ) == 10 ), "Your control group must only have 10 people with 0-1 siblings in it."
assert( len(control[control.Siblings >= 2] ) == 10 ), "Your control group must only have 10 people with 2+ siblings in it."

# %% [markdown]
# ## 3. Create a treatment group
#
# Let's extend what you did onto a new topic.  Using this week's dataset, the course catalog at Illinois, use Python to create a treatment group of 10 courses, using blocking to control for the influence we suspect being an upper-level course might have.
#
# An upper-level course is a course that has a number course number of 300 or higher.  Make sure you have an equal number of lower-level and upper-level courses in your final treatment group.
#
# You can find the course catalog dataset here: https://docs.google.com/spreadsheets/d/1ZnpZpipyui_zIIBblmalRYiyEG1glUKinqJtQxVL04o/edit#gid=0
#
# You have several cells to work in if you need them.  The only requirement is that your final treatment group must be randomly selected and be stored in the variable `treatment`.

# %%
df2 = pd.read_csv("Illinois Course Catalog - Sheet1.csv")
df2
# Out:
#       Year  Term YearTerm Subject  Number  \
# 0     2019  Fall  2019-fa     AAS     100
# 1     2019  Fall  2019-fa     AAS     105
# 2     2019  Fall  2019-fa     AAS     120
# 3     2019  Fall  2019-fa     AAS     199
# 4     2019  Fall  2019-fa     AAS     200
# ...    ...   ...      ...     ...     ...
# 8584  2019  Fall  2019-fa    ZULU     202
# 8585  2019  Fall  2019-fa    ZULU     403
# 8586  2019  Fall  2019-fa    ZULU     404
# 8587  2019  Fall  2019-fa    ZULU     405
# 8588  2019  Fall  2019-fa    ZULU     406
#
#                                        Name  \
# 0              Intro Asian American Studies
# 1     Introduction to Arab American Studies
# 2             Intro to Asian Am Pop Culture
# 3                Undergraduate Open Seminar
# 4                      U.S. Race and Empire
# ...                                     ...
# 8584                     Elementary Zulu II
# 8585                    Intermediate Zulu I
# 8586                   Intermediate Zulu II
# 8587                        Advanced Zulu I
# 8588                       Advanced Zulu II
#
#                                             Description   Credit Hours  \
# 0     Interdisciplinary introduction to the basic co...       3 hours.
# 1     Interdisciplinary introduction to the basic co...       3 hours.
# 2     Introductory understanding of the way U.S. pop...       3 hours.
# 3              May be repeated to a maximum of 6 hours.  1 TO 5 hours.
# 4     Invites students to examine histories and narr...       3 hours.
# ...                                                 ...            ...
# 8584  Continuation of ZULU 201 with introduction of ...       5 hours.
# 8585  Survey of more advanced grammar; emphasis on i...       4 hours.
# 8586  Continuation of ZULU 403; emphasis on increasi...       4 hours.
# 8587  Third year Zulu with emphasis on conversationa...       3 hours.
# 8588  Continuation of Zulu 405 with increased emphas...       3 hours.
#
#                                            Section Info  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                      Same as LLS 200.
# ...                                                 ...
# 8584  Same as AFST 252. Participation in the languag...
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
#                                       Degree Attributes
# 0     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 1                Cultural Studies - US Minority course.
# 2                Cultural Studies - US Minority course.
# 3                                                   NaN
# 4     Humanities - Hist & Phil, and Cultural Studies...
# ...                                                 ...
# 8584                                                NaN
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
# [8589 rows x 10 columns]

# %%
lower = df2[ df2["Number"] < 300]
upper = df2[ df2["Number"] >= 300]

treatment_l = lower.sample(n = 5)
treatment_u = upper.sample(n = 5)
# Out:
#       Year  Term YearTerm Subject  Number                          Name  \
# 4740  2019  Fall  2019-fa      IB     502           Biological Networks
# 8565  2019  Fall  2019-fa      VM     694           Veterinary Medicine
# 3765  2019  Fall  2019-fa      FR     572      Seminar 17thC French Lit
# 3511  2019  Fall  2019-fa    EPSY     582  Advanced Statistical Methods
# 5380  2019  Fall  2019-fa     LER     566   International HR Management
#
#                                             Description   Credit Hours  \
# 4740  This taxon-neutral course prepares students to...       2 hours.
# 8565  To be used to designate a trial or experimenta...  1 TO 4 hours.
# 3765  Discussion and research on a specialized topic...       4 hours.
# 3511  Advanced topics in analyses of variance and co...       4 hours.
# 5380  Human resource management issues examined from...       4 hours.
#
#                                           Section Info Degree Attributes
# 4740                                               NaN               NaN
# 8565                                               NaN               NaN
# 3765                                  May be repeated.               NaN
# 3511  Prerequisite: EPSY 580, PSYC 407, or equivalent.               NaN
# 5380                  Prerequisite: Graduate standing.               NaN

# %%
# Make sure your final answer is in `treatment`:
treatment = pd.concat([treatment_l,treatment_u])
treatment
# Out:
#       Year  Term YearTerm Subject  Number                              Name  \
# 4363  2019  Fall  2019-fa    HIST     211        History of Southern Africa
# 2311  2019  Fall  2019-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3706  2019  Fall  2019-fa      FR     103             Intermediate French I
# 1954  2019  Fall  2019-fa    CHLH     101     Introduction to Public Health
# 5061  2019  Fall  2019-fa     KIN     110      Intro to the Health Sciences
# 4740  2019  Fall  2019-fa      IB     502               Biological Networks
# 8565  2019  Fall  2019-fa      VM     694               Veterinary Medicine
# 3765  2019  Fall  2019-fa      FR     572          Seminar 17thC French Lit
# 3511  2019  Fall  2019-fa    EPSY     582      Advanced Statistical Methods
# 5380  2019  Fall  2019-fa     LER     566       International HR Management
#
#                                             Description   Credit Hours  \
# 4363  Survey of major themes and events in Southern ...       3 hours.
# 2311  Fundamental principles, concepts, and methods ...       3 hours.
# 3706  Continuation of FR 102. Introduces students to...       4 hours.
# 1954  Introduction to the nation's public health sys...       3 hours.
# 5061                    Same as CHLH 110. See CHLH 110.       3 hours.
# 4740  This taxon-neutral course prepares students to...       2 hours.
# 8565  To be used to designate a trial or experimenta...  1 TO 4 hours.
# 3765  Discussion and research on a specialized topic...       4 hours.
# 3511  Advanced topics in analyses of variance and co...       4 hours.
# 5380  Human resource management issues examined from...       4 hours.
#
#                                            Section Info  \
# 4363                                                NaN
# 2311                Prerequisite: MATH 220 or MATH 221.
# 3706  Prerequisite: FR 102 or equivalent, or a place...
# 1954                                                NaN
# 5061                                                NaN
# 4740                                                NaN
# 8565                                                NaN
# 3765                                   May be repeated.
# 3511   Prerequisite: EPSY 580, PSYC 407, or equivalent.
# 5380                   Prerequisite: Graduate standing.
#
#                                       Degree Attributes
# 4363  Humanities - Hist & Phil, and Cultural Studies...
# 2311                  Quantitative Reasoning II course.
# 3706                                                NaN
# 1954                 Social & Beh Sci - Soc Sci course.
# 5061                                                NaN
# 4740                                                NaN
# 8565                                                NaN
# 3765                                                NaN
# 3511                                                NaN
# 5380                                                NaN

# %%
## == TEST CASES for Puzzle 3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( len(treatment) == 10 ), "Your treatment group must only have 10 courses in it."
assert( len(treatment[treatment.Number < 300] ) == 5 ), "Your treatment group must only have 5 lower-level courses in it."
assert( len(treatment[treatment.Number >= 300] ) == 5 ), "Your treatment group must only have 5 upper-level courses in it."

# %% [markdown]
# ## Submit Your Work!
#
# Make sure to **Save and Checkpoint** your notebook, exit Jupyter, and submit your work! :)
