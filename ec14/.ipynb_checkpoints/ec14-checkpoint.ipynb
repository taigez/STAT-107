# %% [markdown]
# # EC Notebook for Lecture 14:
#
# This extra credit Python notebook will let you practice the material you saw in lecture.  Completing all parts of this notebook will earn +1 extra credit point to your grade in STAT 107! :)
#
# This notebook is worth +1 if turned in before 11:30am on **Monday, Sept. 30** *(30 minutes before the next STAT 107 lecture)*.  You can feel free to complete it anytime for extra practice.

# %% [markdown]
# ## 1. Loading pandas and importing data
#
# For this notebook, we will use the "Probability Words" dataset -- to answer a few questions on probabilities.
#
# You can find this dataset here:
# https://docs.google.com/spreadsheets/d/18zQc-cYb376QA478lgWnMbQj39M9wVqHtjbvLP0PTSc/edit#gid=0

# %%
import pandas as pd 


df = pd.read_csv('words.csv')
df
# Out:
#      Almost Certain  Highly Likely  Very Good Chance  Probable  Likely  \
# 0              95.0           85.0              75.0      65.0    75.0
# 1              95.0           85.0              80.0      40.0    80.0
# 2              99.0           90.0              90.0      75.0    70.0
# 3              95.0           80.0              85.0      70.0    65.0
# 4               0.8            0.8               0.7       0.6     0.5
# 5              90.0           90.0              80.0      60.0    60.0
# 6              95.0           90.0              80.0      50.0    60.0
# 7              90.0           80.0              65.0      60.0    70.0
# 8              90.0           90.0              85.0      75.0    80.0
# 9              50.0           90.0              50.0      45.0    50.0
# 10             95.0           70.0              80.0      60.0    80.0
# 11             95.0           95.0              90.0      60.0    70.0
# 12             95.0           90.0              75.0      50.0    60.0
# 13             95.0           90.0              95.0      60.0    70.0
# 14             95.0           90.0              80.0      50.0    60.0
# 15             95.0           80.0              60.0      55.0    65.0
# 16             95.0           85.0              90.0      80.0    75.0
# 17             90.0           80.0              60.0      70.0    60.0
# 18             80.0           90.0              80.0      60.0    70.0
# 19             90.0           85.0              80.0      65.0    75.0
# 20             90.0           80.0              70.0      50.0    70.0
# 21             70.0           75.0              70.0      60.0    60.0
# 22             80.0           75.0              85.0      70.0    60.0
# 23             99.0           90.0              90.0      50.0    95.0
# 24             90.0           80.0              80.0      70.0    70.0
# 25             95.0           95.0              90.0      45.0    80.0
# 26             80.0           90.0              60.0      30.0    50.0
# 27             90.0           85.0              75.0      40.0    65.0
# 28             75.0           75.0              60.0      70.0    60.0
# 29             95.0           90.0              80.0      60.0    70.0
# ..              ...            ...               ...       ...     ...
# 83             95.0           90.0              80.0      75.0    75.0
# 84             95.0           80.0              70.0      65.0    75.0
# 85            100.0           70.0              80.0      10.0    40.0
# 86             80.0           90.0              60.0      50.0    70.0
# 87             80.0           90.0              90.0      50.0    60.0
# 88             85.0           90.0              80.0      60.0    75.0
# 89             90.0           90.0              85.0      75.0    70.0
# 90             95.0           80.0              75.0      60.0    75.0
# 91             90.0           90.0              80.0      75.0    75.0
# 92             60.0           85.0              77.0      65.0    45.0
# 93             95.0           90.0              70.0      85.0    80.0
# 94            100.0           90.0             100.0      80.0    80.0
# 95             70.0           70.0              90.0      80.0    70.0
# 96             85.0           80.0              75.0      40.0    60.0
# 97             95.0           90.0              79.0      60.0    50.0
# 98             95.0           90.0              85.0      75.0    70.0
# 99             90.0           75.0              75.0      66.6    50.0
# 100            99.0           90.0              95.0      70.0    80.0
# 101            90.0           90.0              80.0      50.0    60.0
# 102            98.0           90.0              95.0      50.0    60.0
# 103            85.0           85.0              90.0      60.0    75.0
# 104            80.0           70.0              70.0      60.0    80.0
# 105            95.0           95.0              95.0      75.0    80.0
# 111      10.0          20.0           15.0             10.00              5.0
# 112      25.0          20.0            5.0              2.00             10.0
#
#      Chances are Slight
# 0                  40.0
# 1                  10.0
# 2                   5.0
# 3                  40.0
# 4                   0.4
# 5                  40.0
# 6                  30.0
# 7                  25.0
# 8                  15.0
# 9                  35.0
# 10                  5.0
# 11                 30.0
# 12                 25.0
# 13                 10.0
# 14                 10.0
# 15                 15.0
# 16                 60.0
# 17                 20.0
# 18                 10.0
# 19                 20.0
# 20                 50.0
# 21                 20.0
# 22                 25.0
# 23                 25.0
# 24                 37.0
# 25                 30.0
# 26                 20.0
# 27                  7.0
# 28                  9.0
# 29                 20.0
# ..                  ...
# 83                 10.0
# 84                 10.0
# 85                 20.0
# 86                 30.0
# 87                 15.0
# 88                 30.0
# 89                 20.0
# 90                 25.0
# 91                 20.0
# 92                 67.0
# 93                 15.0
# 94                 50.0
# 95                 10.0
# 96                 55.0
# 97                 20.0
# 98                 10.0
# 99                 15.0
# 100                15.0
# 101                10.0
# 102                 5.0
# 103                15.0
# 104                30.0
# 105                10.0
# 106                10.0
# 107                30.0
# 108                20.0
# 109                30.0
# 110                45.0
# 111                30.0
# 112                25.0
#
# [113 rows x 17 columns]

# %% [markdown]
# ## Question 1
#
# Let's explore a connection between percentage and probability.
#
# Each row in our "Probability Words" dataset is one person's response to their perception of probability words.  If we selected one from the class at random, what is the probability that their perception of "Almost Certain" is 90% or higher?
#
# *Hint: You may need to use* `len(df)` *to find out how many people rows are in a DataFrame after selecting for a certain condition.*

# %%
df_ac = df[df['Almost Certain'] >= 90.0]
df_ac

p_almost_certain_90 = len(df_ac) / len(df)
p_almost_certain_90
# Out:
# 0.7079646017699115

# %%
## == TEST CASES for Puzzle 2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(round(p_almost_certain_90,3)== 0.708)

#
# You will only see this message (with the emoji showing) if you passed all test cases:
#
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Question 2
#
# Now, let's work with random numbers. Remember to ***import random***.
#
# - Let us represent a coin flip as a `0` or `1`.
#   * `0` for heads
#   * `1` for tails
#
# Randomly generate 10 coin flips in `toss1` through `toss10`:

# %%
# import random first
import random


# Now, coin tossing
toss1 = random.randint(0,1)
toss2 = random.randint(0,1)
toss3 = random.randint(0,1)
toss4 = random.randint(0,1)
toss5 = random.randint(0,1)
toss6 = random.randint(0,1)
toss7 = random.randint(0,1)
toss8 = random.randint(0,1)
toss9 = random.randint(0,1)
toss10 = random.randint(0,1)



# Some basic calculations based on your tosses:
heads_ct = toss1 + toss2 + toss3 + toss4 + toss5 + toss6+ toss7 + toss8 + toss9 + toss10
tails_ct = 10 - heads_ct
probability_head = heads_ct / 10

print(f"Number of heads: {heads_ct}")
print(f"Number of tails: {tails_ct}")
print()
print(f"P(head) from your 10 tosses: {probability_head}")
# Out:
# Number of heads: 3
# Number of tails: 7
#
# P(head) from your 10 tosses: 0.3

# %% [markdown]
# ## Run it Again
#
# Run the previous cell several times -- watch how the numbers differ! :)

# %%
## == TEST CASES for Puzzle 2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert((0 <= probability_head) and (probability_head <= 1)), "The probability is always between 0 and 1, isn't it?"

#
# You will only see this message (with the emoji showing) if you passed all test cases:
#
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# Interested in Magic! Run your simulation again and see if the probability of heads changes or not!
# What could be the possible reason. You don't have to answer it here, just think about it!

# %% [markdown]
# ## Submit Your Work!
#
# Make sure to **Save and Checkpoint** your notebook, exit Jupyter, and submit your work! :)
