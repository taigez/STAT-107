# %% [markdown]
# # EC Notebook for Lecture 5: Combining DataFrames
#
# This extra credit Python notebook will let you practice the material you saw in lecture.  Completing all parts of this notebook will earn +1 extra credit point to your grade in STAT 107! :)
#
# This notebook is worth +1 if turned in before 11:30am on **Monday, Sept. 9** *(30 minutes before the next STAT 107 lecture)*.  You can feel free to complete it anytime for extra practice.

# %% [markdown]
# ## 1. Loading pandas and importing data
#
# For this notebook, we will use the "Course Catalog" dataset that is our dataset of the week.
#
# Here's the link: https://docs.google.com/spreadsheets/d/1ZnpZpipyui_zIIBblmalRYiyEG1glUKinqJtQxVL04o/edit#gid=0
#
# Use the following cell to load the pandas library and read the DataSet as a DataFrame:

# %%
import pandas as pd 
df = pd.read_csv("Illinois Course Catalog - Sheet1.csv")
df
# Out:
#       Year  Term YearTerm Subject  Number  \
# 0     2019  Fall  2019-fa     AAS     100
# 1     2019  Fall  2019-fa     AAS     105
# 2     2019  Fall  2019-fa     AAS     120
# 3     2019  Fall  2019-fa     AAS     199
# 4     2019  Fall  2019-fa     AAS     200
# ...    ...   ...      ...     ...     ...
# 8584  2019  Fall  2019-fa    ZULU     202
# 8585  2019  Fall  2019-fa    ZULU     403
# 8586  2019  Fall  2019-fa    ZULU     404
# 8587  2019  Fall  2019-fa    ZULU     405
# 8588  2019  Fall  2019-fa    ZULU     406
#
#                                        Name  \
# 0              Intro Asian American Studies
# 1     Introduction to Arab American Studies
# 2             Intro to Asian Am Pop Culture
# 3                Undergraduate Open Seminar
# 4                      U.S. Race and Empire
# ...                                     ...
# 8584                     Elementary Zulu II
# 8585                    Intermediate Zulu I
# 8586                   Intermediate Zulu II
# 8587                        Advanced Zulu I
# 8588                       Advanced Zulu II
#
#                                             Description   Credit Hours  \
# 0     Interdisciplinary introduction to the basic co...       3 hours.
# 1     Interdisciplinary introduction to the basic co...       3 hours.
# 2     Introductory understanding of the way U.S. pop...       3 hours.
# 3              May be repeated to a maximum of 6 hours.  1 TO 5 hours.
# 4     Invites students to examine histories and narr...       3 hours.
# ...                                                 ...            ...
# 8584  Continuation of ZULU 201 with introduction of ...       5 hours.
# 8585  Survey of more advanced grammar; emphasis on i...       4 hours.
# 8586  Continuation of ZULU 403; emphasis on increasi...       4 hours.
# 8587  Third year Zulu with emphasis on conversationa...       3 hours.
# 8588  Continuation of Zulu 405 with increased emphas...       3 hours.
#
#                                            Section Info  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                      Same as LLS 200.
# ...                                                 ...
# 8584  Same as AFST 252. Participation in the languag...
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
#                                       Degree Attributes
# 0     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 1                Cultural Studies - US Minority course.
# 2                Cultural Studies - US Minority course.
# 3                                                   NaN
# 4     Humanities - Hist & Phil, and Cultural Studies...
# ...                                                 ...
# 8584                                                NaN
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
# [8589 rows x 10 columns]

# %% [markdown]
# ## 2. Selecting all SUBJ 100 and SUBJ 101
#
# In many subjects, 100 and 101 courses serve as freshman entry-level courses.  Create single DataFrame called `entryCourses` that contains all courses with numbers `100` or `101`.  *There are MANY different ways you can do this, including using `df.merge` if needed.*

# %%
subj_100 = df[ df["Number"] == 100]
subj_101 = df[ df["Number"] == 101]
print(len(subj_100))
print(len(subj_101))
len(subj_100)+len(subj_101)

entryCourses = pd.concat([subj_100,subj_101])
entryCourses
# Out:
# 48
# 66
#       Year  Term YearTerm Subject  Number                                Name  \
# 0     2019  Fall  2019-fa     AAS     100        Intro Asian American Studies
# 49    2019  Fall  2019-fa     ABE     100  Intro Agric &amp; Biological Engrg
# 149   2019  Fall  2019-fa     ACE     100          Agr Cons and Resource Econ
# 300   2019  Fall  2019-fa      AE     100      Intro to Aerospace Engineering
# 383   2019  Fall  2019-fa    AFRO     100        Intro to African American St
# ...    ...   ...      ...     ...     ...                                 ...
# 7874  2019  Fall  2019-fa    SPAN     101                Elementary Spanish I
# 8147  2019  Fall  2019-fa    THEA     101        Introduction to Theatre Arts
# 8360  2019  Fall  2019-fa     UKR     101                   Basic Ukrainian I
# 8368  2019  Fall  2019-fa      UP     101       Introduction to City Planning
# 8576  2019  Fall  2019-fa    YDSH     101                 Beginning Yiddish I
#
#                                             Description Credit Hours  \
# 0     Interdisciplinary introduction to the basic co...     3 hours.
# 49    Introduction to the engineering profession wit...     1 hours.
# 149   Principles of microeconomics; demand, producti...     4 hours.
# 300   Introduction to the Aerospace Engineering curr...     2 hours.
# 383   Interdisciplinary introduction to the basic co...     3 hours.
# ...                                                 ...          ...
# 7874  Intensive course for beginner students of Span...     4 hours.
# 8147  Introduction to the arts of theater for non-ma...     3 hours.
# 8360  Oral and written work on basic pronunciation, ...     4 hours.
# 8368  Provides an introduction to urban and regional...     3 hours.
# 8576  Course develops basic conversational and readi...     4 hours.
#
#                                            Section Info  \
# 0                                                   NaN
# 49                                                  NaN
# 149   Credit is not given for ACE 100 if credit for ...
# 300                                                 NaN
# 383                                                 NaN
# ...                                                 ...
# 7874                                                NaN
# 8147   Credit not given for both THEA 101 and THEA 102.
# 8360                                                NaN
# 8368                                                NaN
# 8576                                                NaN
#
#                                       Degree Attributes
# 0     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 49                                                  NaN
# 149                  Social & Beh Sci - Soc Sci course.
# 300                                                 NaN
# 383   Social & Beh Sci - Soc Sci, and Cultural Studi...
# ...                                                 ...
# 7874                                                NaN
# 8147                    Humanities - Lit & Arts course.
# 8360                                                NaN
# 8368                                                NaN
# 8576                                                NaN
#
# [114 rows x 10 columns]

# %%
## == TEST CASES for Puzzle 2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(entryCourses) == 116 ), "`entryCourses` must contain all 116 entry-level courses."
assert( len(entryCourses[entryCourses.Number == 100] ) == 48 ), "`entryCourses` must contain all 48 courses as SUBJ `100`."
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-e00cab48aad4> in <module>
#       3 # - If this cell runs without any error our output, you PASSED all test cases!
#       4 # - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
# ----> 5 assert( len(entryCourses) == 116 ), "`entryCourses` must contain all 116 entry-level courses."
#       6 assert( len(entryCourses[entryCourses.Number == 100] ) == 48 ), "`entryCourses` must contain all 48 courses as SUBJ `100`."
#
# AssertionError: `entryCourses` must contain all 116 entry-level courses.

# %% [markdown]
# ## 3. Creating a `control` and `treatment` group
#
# Using the `entryCourses` you created in Puzzle 2, create a `treatment` and `control` group that each contain 50 random courses to use an experiment you are developing.
#
# *Remember: A course cannot be in both a treatment and control group!*

# %%
# Create the control group:


control = entryCourses.sample(n = 50)
control
# Out:
# 50

# %%
# Create the treatment group:

pre_treatment = entryCourses[ ~entryCourses.index.isin(control.index)]
treatment = pre_treatment.sample(n = 50)
treatment
# Out:
#       Year  Term YearTerm Subject  Number  \
# 528   2019  Fall  2019-fa    AGED     100
# 4016  2019  Fall  2019-fa     GER     101
# 8123  2019  Fall  2019-fa      TE     100
# 6612  2019  Fall  2019-fa      NS     101
# 5055  2019  Fall  2019-fa     KIN     101
# 6106  2019  Fall  2019-fa     MUS     101
# 5544  2019  Fall  2019-fa    MACS     101
# 8002  2019  Fall  2019-fa    STAT     100
# 577   2019  Fall  2019-fa     AIS     101
# 6875  2019  Fall  2019-fa     POL     101
# 5213  2019  Fall  2019-fa     LAS     100
# 4935  2019  Fall  2019-fa    ITAL     101
# 149   2019  Fall  2019-fa     ACE     100
# 6786  2019  Fall  2019-fa    PHYS     100
# 2194  2019  Fall  2019-fa     CMN     101
# 1066  2019  Fall  2019-fa    ARTE     101
# 0     2019  Fall  2019-fa     AAS     100
# 8576  2019  Fall  2019-fa    YDSH     101
# 1533  2019  Fall  2019-fa    BIOE     100
# 3887  2019  Fall  2019-fa    GEOG     101
# 2633  2019  Fall  2019-fa    DANC     101
# 4583  2019  Fall  2019-fa    HORT     100
# 1953  2019  Fall  2019-fa    CHLH     100
# 7543  2019  Fall  2019-fa      SE     100
# 6787  2019  Fall  2019-fa    PHYS     101
# 7789  2019  Fall  2019-fa    SOCW     101
# 3955  2019  Fall  2019-fa    GEOL     100
# 6713  2019  Fall  2019-fa    PHIL     101
# 7363  2019  Fall  2019-fa    RHET     101
# 3106  2019  Fall  2019-fa     ENG     100
# 1637  2019  Fall  2019-fa     BUS     101
# 2632  2019  Fall  2019-fa    DANC     100
# 8368  2019  Fall  2019-fa      UP     101
# 3886  2019  Fall  2019-fa    GEOG     100
# 383   2019  Fall  2019-fa    AFRO     100
# 2626  2019  Fall  2019-fa    CZCH     101
# 5617  2019  Fall  2019-fa    MATH     101
# 5473  2019  Fall  2019-fa     LLS     100
# 5766  2019  Fall  2019-fa     MCB     100
# 7372  2019  Fall  2019-fa     RST     100
# 5394  2019  Fall  2019-fa    LING     100
# 2311  2019  Fall  2019-fa      CS     101
# 2978  2019  Fall  2019-fa    ECON     101
# 605   2019  Fall  2019-fa    ANSC     101
# 3294  2019  Fall  2019-fa    ENVS     101
# 7544  2019  Fall  2019-fa      SE     101
# 5860  2019  Fall  2019-fa    MDIA     100
# 6504  2019  Fall  2019-fa    NRES     101
# 6906  2019  Fall  2019-fa      PS     100
# 7440  2019  Fall  2019-fa    RUSS     101
#
#                                                    Name  \
# 528                     Intro to Ag &amp; Leadership Ed
# 4016                                 Beginning German I
# 8123  Introduction to Innovation, Leadership and Eng...
# 6612                      Introduction to Naval Science
# 5055                                   Dance Activities
# 6106                        Music Theory and Practice I
# 5544                                 Intro to the Media
# 8002                                         Statistics
# 577                        Intro to Amer Indian Studies
# 6875                                Elementary Polish I
# 5213          Success in LAS for International Students
# 4935                               Elementary Italian I
# 149                          Agr Cons and Resource Econ
# 6786                             Thinking About Physics
# 2194                                    Public Speaking
# 1066                           Art, Design, and Society
# 0                          Intro Asian American Studies
# 8576                                Beginning Yiddish I
# 1533                    Bioengineering Freshman Seminar
# 3887                 Global Development&amp;Environment
# 2633                                     Modern Dance I
# 4583                       Introduction to Horticulture
# 1953                                Contemporary Health
# 7543                                Introduction to ISE
# 6787                   College Physics: Mech &amp; Heat
# 7789                           SOCW Orientation Seminar
# 3955                                       Planet Earth
# 6713                         Introduction to Philosophy
# 7363                              Principles of Writing
# 3106                            Engineering Orientation
# 1637           Professional Responsibility and Business
# 2632                        Intro to Contemporary Dance
# 8368                      Introduction to City Planning
# 3886                        Introduction to Meteorology
# 383                        Intro to African American St
# 2626                                 Elementary Czech I
# 5617                            Thinking Mathematically
# 5473                        Intro Latina/Latino Studies
# 5766                          Introductory Microbiology
# 7372   Recreation, Sport, and Tourism in Modern Society
# 5394                          Intro to Language Science
# 2311                   Intro Computing: Engrg &amp; Sci
# 2978                          Introduction to Economics
# 605                          Contemporary Animal Issues
# 3294                     Introduction to Energy Sources
# 7544                  Engineering Graphics &amp; Design
# 5860                       College of Media Orientation
# 6504                      Wildlife Conserv 21st Century
# 6906                         Intro to Political Science
# 7440                               First-Year Russian I
#
#                                             Description Credit Hours  \
# 528   Overview of agricultural and leadership educat...     2 hours.
# 4016  Oral practice, reading, and grammar for beginn...     4 hours.
# 8123  Introduction course to innovation, leadership,...     1 hours.
# 6612  Naval organization and management practices ex...     2 hours.
# 5055  Skills and knowledge essential for leisure-tim...     1 hours.
# 6106  Fundamental theory including terminology and n...     2 hours.
# 5544  Introduces students to core issues in communic...     3 hours.
# 8002  First course in probability and statistics at ...     3 hours.
# 577   Interdisciplinary introduction surveys the sto...     3 hours.
# 6875  Oral and written work on basic pronunciation, ...     4 hours.
# 5213  Prepares international students for their tran...     2 hours.
# 4935        For students who have no credit in Italian.     4 hours.
# 149   Principles of microeconomics; demand, producti...     4 hours.
# 6786  Conceptual and problem solving skills in prepa...     2 hours.
# 2194  Preparation and presentation of short informat...     3 hours.
# 1066  This course provides an introductory forum for...     2 hours.
# 0     Interdisciplinary introduction to the basic co...     3 hours.
# 8576  Course develops basic conversational and readi...     4 hours.
# 1533  Bioengineering Freshman Seminar provides a bro...     1 hours.
# 3887  Introduces geographical perspectives on enviro...     3 hours.
# 2633  Introduction to basic dance technique and move...     2 hours.
# 4583  Basic principles of plant growth and developme...     3 hours.
# 1953  Examines concepts of health and health promoti...     3 hours.
# 7543  Overview of the engineering profession, the In...     1 hours.
# 6787  Newton's Laws, work and energy, rotational mot...     5 hours.
# 7789  Informational orientation seminar for Social W...     2 hours.
# 3955  Introduces non-science majors to physical aspe...     3 hours.
# 6713  Consideration of some main problems of philoso...     3 hours.
# 7363  Instruction in structuring academic, argumenta...     4 hours.
# 3106  Orientation required of new freshmen in the Co...     0 hours.
# 1637  Introduces business students to professional r...     3 hours.
# 2632  Overview of major works, figures, and trends r...     3 hours.
# 8368  Provides an introduction to urban and regional...     3 hours.
# 3886                    Same as ATMS 100. See ATMS 100.     3 hours.
# 383   Interdisciplinary introduction to the basic co...     3 hours.
# 2626  Develops basic proficiency in Czech in listeni...     4 hours.
# 5617  Designed for students in majors that do not sp...     3 hours.
# 5473  Interdisciplinary introduction to the basis fo...     3 hours.
# 5766  Introduction to the principal activities and p...     3 hours.
# 7372  This course examines central issues in definin...     3 hours.
# 5394  Introduction to the theory and methodology of ...     3 hours.
# 2311  Fundamental principles, concepts, and methods ...     3 hours.
# 2978  General survey of the operation of the economi...     4 hours.
# 605   Provides an understanding of fundamental issue...     3 hours.
# 3294                    Same as NPRE 101. See NPRE 101.     3 hours.
# 7544  Computer-aided design (CAD) software modeling ...     3 hours.
# 5860  College of Media Orientation is designed to bu...     1 hours.
# 6504  This course is an introduction to the conserva...     3 hours.
# 6906  Surveys the major concepts and approaches empl...     3 hours.
# 7440  Oral-aural practice and elements of grammar, r...     4 hours.
#
#                                            Section Info  \
# 528                                                 NaN
# 4016                                                NaN
# 8123                                                NaN
# 6612               Prerequisite: Consent of instructor.
# 5055  May be repeated; more than one activity (Secti...
# 6106  Credit is not given for both MUS 101 and MUS 1...
# 5544      Prerequisite: Freshman or sophomore standing.
# 8002  Credit is not given for both STAT 100 and any ...
# 577                                                 NaN
# 6875                                                NaN
# 5213  Serves as a complement to LAS 101/LAS 102/LAS ...
# 4935        For students who have no credit in Italian.
# 149   Credit is not given for ACE 100 if credit for ...
# 6786  Prerequisite: Credit or concurrent registratio...
# 2194  Credit is not given for both CMN 101 and eithe...
# 1066                                                NaN
# 0                                                   NaN
# 8576                                                NaN
# 1533        Prerequisite: Bioengineering Freshmen Only.
# 3887                                                NaN
# 2633           May be repeated to a maximum of 8 hours.
# 4583  Credit is not given for both HORT 100 and HORT...
# 1953                                                NaN
# 7543                                                NaN
# 6787  Credit is not given for both PHYS 101 and eith...
# 7789                                                NaN
# 3955  Credit is not given for both GEOL 100 and GEOL...
# 6713  Credit is not given for both PHIL 101 and PHIL...
# 7363  Credit is not given for both RHET 101 and RHET...
# 3106                     Approved for S/U grading only.
# 1637  Prerequisite: First Semester Freshman, Interco...
# 2632                              For non-dance majors.
# 8368                                                NaN
# 3886                    Same as ATMS 100. See ATMS 100.
# 383                                                 NaN
# 2626                                                NaN
# 5617  Prerequisite: Three years of high school mathe...
# 5473                                                NaN
# 5766  Credit is not given for both MCB 100 and MCB 3...
# 7372                                                NaN
# 5394                                                NaN
# 2311                Prerequisite: MATH 220 or MATH 221.
# 2978                                                NaN
# 605                                                 NaN
# 3294                                                NaN
# 7544    Credit is not given for both SE 101 and ME 170.
# 5860                                                NaN
# 6504                                                NaN
# 6906    Credit is not given for both PS 100 and PS 200.
# 7440                                                NaN
#
#                                       Degree Attributes
# 528                                                 NaN
# 4016                                                NaN
# 8123                                                NaN
# 6612                                                NaN
# 5055                                                NaN
# 6106                                                NaN
# 5544                       Advanced Composition course.
# 8002                   Quantitative Reasoning I course.
# 577   Humanities - Hist & Phil, and Cultural Studies...
# 6875                                                NaN
# 5213                                                NaN
# 4935                                                NaN
# 149                  Social & Beh Sci - Soc Sci course.
# 6786                                                NaN
# 2194                                                NaN
# 1066                                                NaN
# 0     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 8576                                                NaN
# 1533                                                NaN
# 3887  Cultural Studies - Non-West, and Social & Beh ...
# 2633                                                NaN
# 4583                                                NaN
# 1953                 Social & Beh Sci - Soc Sci course.
# 7543                                                NaN
# 6787  Nat Sci & Tech - Phys Sciences, and Quantitati...
# 7789                                                NaN
# 3955             Nat Sci & Tech - Phys Sciences course.
# 6713                   Humanities - Hist & Phil course.
# 7363                              Composition I course.
# 3106                                                NaN
# 1637                                                NaN
# 2632  Humanities - Lit & Arts, and Cultural Studies ...
# 8368                                                NaN
# 3886             Nat Sci & Tech - Phys Sciences course.
# 383   Social & Beh Sci - Soc Sci, and Cultural Studi...
# 2626                                                NaN
# 5617                                                NaN
# 5473  Social & Beh Sci - Soc Sci, and Cultural Studi...
# 5766             Nat Sci & Tech - Life Sciences course.
# 7372                 Social & Beh Sci - Soc Sci course.
# 5394                 Social & Beh Sci - Soc Sci course.
# 2311                  Quantitative Reasoning II course.
# 2978                 Social & Beh Sci - Soc Sci course.
# 605                                                 NaN
# 3294  Nat Sci & Tech - Phys Sciences, and Quantitati...
# 7544                                                NaN
# 5860                                                NaN
# 6504                                                NaN
# 6906                 Social & Beh Sci - Soc Sci course.
# 7440                                                NaN

# %%
## == TEST CASES for Puzzle 3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( len(control) == 50 ), "The control group must contain exactly 50 courses."
assert( len(treatment) == 50 ), "The control group must contain exactly 50 courses."

assert( len(control[control.Number > 101] ) == 0 ), "`control` must contain only entry-level courses."
assert( len(treatment[treatment.Number > 101] ) == 0 ), "`treatment` must contain only entry-level courses."

assert( len(pd.merge(control, treatment, how='inner', on=['Subject', 'Number'])) == 0 ), "Courses in `treatment` and `control` must be different."

# %% [markdown]
# ## Submit Your Work!
#
# Make sure to **Save and Checkpoint** your notebook, exit Jupyter, and submit your work! :)
